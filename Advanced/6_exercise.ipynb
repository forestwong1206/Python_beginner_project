# %%
# Import libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading dataset
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data clean up
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_usa = df[df['job_country']=='United States'].copy()

# %%
df_usa['job_posted_month'] = df_usa['job_posted_date'].dt.strftime('%B')

# %%
usa_pivot = df_usa.pivot_table(index= 'job_posted_month', columns='job_title_short', aggfunc= 'size')
usa_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# April                          565              40          6049
# August                         903              39          6634
# December                       648              40          3979
# February                       447              24          6124
# January                        527              36          8494
# July                           581              39          5201
# June                           446              32          5683
# March                          438              19          6218
# May                            279              20          4993
# November                       719              36          4531
# October                        932              48          5271
# September                      897              50          4639
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
usa_pivot.reset_index(inplace=True)

# %%
usa_pivot['month_no'] = pd.to_datetime(usa_pivot['job_posted_month'], format='%B').dt.month
usa_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 0                          April               565              40
# 1                         August               903              39
# 2                       December               648              40
# 3                       February               447              24
# 4                        January               527              36
# 5                           July               581              39
# 6                           June               446              32
# 7                          March               438              19
# 8                            May               279              20
# 9                       November               719              36
# 10                       October               932              48
# 11                     September               897              50
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# ...

# %%
usa_pivot.sort_values('month_no', inplace = True)
usa_pivot.set_index('job_posted_month', inplace = True)
usa_pivot.drop(columns='month_no', inplace = True)

# %%
usa_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
top_3 = df_usa['job_title_short'].value_counts().head(3)
top_3 = top_3.index.to_list()
top_3
# Out:
# ['Data Analyst', 'Data Scientist', 'Data Engineer']

# %%
usa_pivot[top_3]
# Out:
# job_title_short   Data Analyst  Data Scientist  Data Engineer
# job_posted_month
# January                   8494            6915           2655
# February                  6124            4956           3060
# March                     6218            4779           3183
# April                     6049            4867           2801
# May                       4993            4377           2976
# June                      5683            4645           2893
# July                      5201            4876           2570
# August                    6634            6318           3269
# September                 4639            4568           3224
# October                   5271            4882           3015
# November                  4531            4175           2793
# December                  3979            3472           2641
