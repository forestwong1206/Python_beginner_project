# %% [markdown]
# # Introduction: Data Type
# *   Text Type: **str**
# *   Numeric Types: **int, float**
# *   Sequence Types: **list, tuples**
# *   Mapping Type: **dict**
# *   Set Types: **set**

# %%
company_name = "GMM TV" # set a new string variable
year_established = 1995 # set a new integer variable
company_age = float(31) # turn an integer into float

print("Company Name:    ", company_name)
print("Year_established:", year_established)
print("Company Age:     ", company_age)
# Out:
# Company Name:     GMM TV
# Year_established: 1995
# Company Age:      31.0

# %%
type(company_name) # check the data type
# note that Jupiter notebook will always help print the last object, be aware to use print() in actual coding
# Out:
# str

# %% [markdown]
# Note: Use help() to view investigate data types, functions, methods...

# %% [markdown]
# # String
# *   Texts quoted in "" or ''
# *   List item

# %%
name = "love pattranite" # this created the variable 'name' as a string
# various methods (functions for string) can be used

# %% [markdown]
# Methods

# %%
name.upper()
# make all letter uppercase
# Out:
# 'LOVE PATTRANITE'

# %%
name.capitalize()
# make first letter uppercase
# Out:
# 'Love pattranite'

# %%
name.title()
# make first letter of every word uppercase
# Out:
# 'Love Pattranite'

# %%
name.count("t")
# count how many times this appeared
# Out:
# 3

# %%
len(name)
# count the length of the variable
# Out:
# 15

# %%
name.replace("l","d")
# replace first "" by the second ""
# Out:
# 'dove pattranite'

# %% [markdown]
# There are some Dunder methods e.g. \_\_add__, but they work the same as using +.

# %% [markdown]
# Formatting

# %% [markdown]
# Adding
# *  strings can be added to form a new string through +

# %%
full_name = name + " limpatiyakorn"
full_name
# Out:
# 'love pattranite limpatiyakorn'

# %% [markdown]
# f'str
# *  f'str can help format the string as you type it in the cell

# %%
print(f"Name: {name} \nFull name: {full_name}")
# Out:
# Name: love pattranite
# Full name: love pattranite limpatiyakorn

# %% [markdown]
# str.format()
# *  just like f'str but allow for reuse of argument

# %%
print('Name: {}  \nFull Name: {}'.format(name, full_name))
print('Name: {name}  \nFull Name: {full_name}'.format(name=name, full_name=full_name))
# same as above
# Out:
# Name: love pattranite
# Full Name: love pattranite limpatiyakorn
# Name: love pattranite
# Full Name: love pattranite limpatiyakorn

# %% [markdown]
# join()
# *   Joining a list with iterable items

# %%
series = ["23.5", "Whale Store XOXO", "Girl Rules"]

"Series Played In:  " + ", ".join(series)
# Out:
# 'Series Played In:  23.5, Whale Store XOXO, Girl Rules'

# %% [markdown]
# # Operators
#
#
# *   Arithmetic operators (+, -, *, /, //, %,  **)
# *   Assignment operators (=, +=, -=, *=, /=, //=, %=,  **=)
# *   Comparison operators (==, !=, >, <, >=, <=)

# %% [markdown]
# Arithmetic operators

# %%
print(10+3)
print(10-3)
print(10*3)
print(10/3)
print(10//3)
# Floor division
print(10%3)
# Remainder
print(10**3)
# Exponential, power
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %% [markdown]
# Assignment operators

# %%
x = 10
x += 3
# Same as x = x + 3
# The rest works the same
print(x)
# Out:
# 13

# %% [markdown]
# Comparison operators

# %%
10000 == 10000
# Out:
# True

# %%
10000 != 10000
# Out:
# False

# %% [markdown]
# # Conditional Statement
#
#
# *   if
# *   elif
# *   else

# %%
score_235 = 8.5
score_whalestore = 8.3
score_girlrules = 7.9

# %%
if score_235 > score_whalestore :
  print('23.5 is scored higher than whale store')
# Out:
# 23.5 is scored higher than whale store

# %%
if score_whalestore > score_235:
  print('whale store is scored higher than 23.5')
elif score_whalestore > score_girlrules:
  print('whale store is scored higher than girl rules')
# Out:
# whale store is scored higher than girl rules

# %%
if score_whalestore > score_235:
  print('whale store is scored higher than 23.5')
elif score_girlrules > score_whalestore:
  print('girl rules is scored higher than whale store')
else:
  print('23.5 is scored highest')
# Out:
# 23.5 is scored highest

# %% [markdown]
# Note: use pass to leave the action empty

# %% [markdown]
# Use **and** in the condition

# %%
if score_whalestore < score_235 and score_girlrules < score_whalestore:
  print('23.5 is scored highest')
# Out:
# 23.5 is scored highest

# %% [markdown]
# # Container Data Type
#
# | Feature          | List                                  | Dictionary                           | Set                                | Tuple                             |
# |------------------|---------------------------------------|--------------------------------------|------------------------------------|-----------------------------------|
# | Syntax           | `[item1, item2, ...]`                 | `{'key1': value1, 'key2': value2}`   | `{item1, item2, ...}`              | `(item1, item2, ...)` or `item,`  |
# | Type of Data     | Sequence                              | Mapping                              | Set                                | Sequence                          |
# | Order            | Ordered                               | Unordered                            | Unordered                          | Ordered                           |
# | Indexing         | Yes (by index)                        | Yes (by key)                         | No                                 | Yes (by index)                    |
# | Duplicate Values | Allowed                               | Values can be duplicated, keys cannot| Not allowed                        | Allowed                           |
# | Mutability       | Mutable                               | Mutable                              | Mutable                            | Immutable                         |
# | Usage            | For a collection of ordered items     | For key-value pairs                  | For unique items                   | For fixed data                    |

# %% [markdown]
# ##List

# %%
series = ["24.5", "Whale Store XOXO", "Girl Rules"]

# %% [markdown]
# Indexing

# %%
series[0]
# Out:
# '24.5'

# %%
series[0] = "23.5"

# %% [markdown]
# Methods

# %%
series.append("Ditto")
series
# Out:
# ['23.5', 'Whale Store XOXO', 'Girl Rules', 'Ditto']

# %%
len(series)
# Out:
# 4

# %%
series.remove("Girl Rules")
series
# Out:
# ['23.5', 'Whale Store XOXO', 'Ditto']

# %%
series.insert(2, "Girl Rules")
series
# insert a new item after an existing item in the list
# Out:
# ['23.5', 'Whale Store XOXO', 'Girl Rules', 'Ditto']

# %% [markdown]
# Joining lists

# %%
previous_series = ["2gether", "Bad Buddy", "Home School"]

# %%
print(previous_series + series)
# Out:
# ['2gether', 'Bad Buddy', 'Home School', '23.5', 'Whale Store XOXO', 'Girl Rules', 'Ditto']

# %%
for x in series:
    previous_series.append(x)

print(previous_series)
# Out:
# ['2gether', 'Bad Buddy', 'Home School', '23.5', 'Whale Store XOXO', 'Girl Rules', 'Ditto']

# %%
previous_series = ["2gether", "Bad Buddy", "Home School"]

previous_series.extend(series)
print(previous_series)
# Out:
# ['2gether', 'Bad Buddy', 'Home School', '23.5', 'Whale Store XOXO', 'Girl Rules', 'Ditto']

# %% [markdown]
# Slicing list

# %%
first_two = series[0:2]
first_two
# Out:
# ['23.5', 'Whale Store XOXO']

# %%
odd_number_series = series[::2]
odd_number_series
# use steps to do odd number
# Out:
# ['23.5', 'Girl Rules']

# %% [markdown]
# Unpack list

# %%
serie1, serie2, serie3, serie4 = series
print(serie1)
print(serie2)
print(serie3)
print(serie4)
# Out:
# 23.5
# Whale Store XOXO
# Girl Rules
# Ditto

# %%
serie1, serie2, *serie_rest = series
print(serie1)
print(serie2)
print(serie_rest)
# Out:
# 23.5
# Whale Store XOXO
# ['Girl Rules', 'Ditto']

# %% [markdown]
# ##Dictionaries
#
#
# *   Store {key:value, ...}

# %%
character_name = {
    "Ciize" : "Alpha",
    "Love" : "Sun",
    "Milk" : "Ongsa"
}

# %%
character_name["Ciize"]
# Out:
# 'Alpha'

# %% [markdown]
# Methods

# %% [markdown]
# Use keys(), values(), and items() to fetch the keys, values, and each pair. Use get() to fetch the value to the specific key.

# %%
character_name.keys()
# Out:
# dict_keys(['Ciize', 'Love', 'Milk'])

# %%
character_name.values()
# Out:
# dict_values(['Alpha', 'Sun', 'Ongsa'])

# %%
character_name.items()
# Out:
# dict_items([('Ciize', 'Alpha'), ('Love', 'Sun'), ('Milk', 'Ongsa')])

# %%
character_name.get("Ciize")
# Out:
# 'Alpha'

# %% [markdown]
# Remove and add items

# %%
character_name.pop("Ciize")
character_name
# Out:
# {'Love': 'Sun', 'Milk': 'Ongsa'}

# %%
character_name["Ciize"] = "Alpha"
character_name
# Out:
# {'Love': 'Sun', 'Milk': 'Ongsa', 'Ciize': 'Alpha'}

# %%
character_name.update({"View": "Aylin"})
character_name
# Out:
# {'Love': 'Sun', 'Milk': 'Ongsa', 'Ciize': 'Alpha', 'View': 'Aylin'}

# %% [markdown]
# ##Set
#
#
# *   Unchangeable (but adding and removing possible), unorder, unindexed

# %%
character = {"Pha", "Sun", "Meawnam", "Gorya"}
character
# Out:
# {'Gorya', 'Meawnam', 'Pha', 'Sun'}

# %% [markdown]
# Adding and removing

# %%
character.add("Rafah")
character
# Out:
# {'Gorya', 'Meawnam', 'Pha', 'Rafah', 'Sun'}

# %%
character.remove("Pha")
character
# Out:
# {'Gorya', 'Meawnam', 'Rafah', 'Sun'}

# %% [markdown]
# set can be used for removing dplicated item in lists

# %%
name_list = ["Pha", "Sun", "Pha", "Meawnam", "Sun", "Pha"]
set(name_list)
# Out:
# {'Meawnam', 'Pha', 'Sun'}

# %%
name_list = list(set(name_list))
name_list
# Out:
# ['Meawnam', 'Sun', 'Pha']

# %% [markdown]
# ##Tuples
#
#
#
# *   Unchangeable at all (not even adding and removing)
# *   Indexed

# %%
partners = ("Ink", "Ongsa", "Wan")
partners
# Out:
# ('Ink', 'Ongsa', 'Wan')

# %% [markdown]
# Slicing

# %%
partners[0]
# Out:
# 'Ink'

# %%
partners[:2]
# Out:
# ('Ink', 'Ongsa')

# %% [markdown]
# Adding (and removing) items

# %% [markdown]
# 1.   Turn it into a list and turn it back (same for removing)

# %%
partners = list(partners)
partners.append("Shasha")
partners = tuple(partners)
partners
# Out:
# ('Ink', 'Ongsa', 'Wan', 'Shasha')

# %% [markdown]
# 2.   Turn it into a list and turn it back

# %%
partners2 = ("Dear", "Earth")
partners += partners2
partners
# Out:
# ('Ink', 'Ongsa', 'Wan', 'Shasha', 'Dear', 'Earth')

# %% [markdown]
# 3.  del

# %%
del partners2
partners2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2914/1960992333.py in <cell line: 0>()
#       1 del partners2
# ----> 2 partners2
#
# NameError: name 'partners2' is not defined

# %% [markdown]
# Use turple to list out a range of numbers
#
#
# *   range(start, stop, step)

# %%
tuple(range(10))

# %%
list(range(2,50,5))

# %% [markdown]
# # Operators (Part2)
# * Logical operators (and, or, not)
# * Identity operators (is, not)
# * Membership operators (in, not in)
# * Bitwise operators (&, |, ^, ~, >>, <<)

# %% [markdown]
# and, or, not

# %%
milk_love_love = True
milk_love_ciize = False
milk_love_love and milk_love_ciize

# %%
milk_love_love or milk_love_ciize

# %% [markdown]
# is, not
# * Need to be identical (stored in same memory)
# * Integers does not count as identical

# %%
love_age = 26
film_age = love_age
film_age is love_age

# %% [markdown]
# in, not in

# %%
"love" in "love pattranite"

# %%
"lunar" in ["lunar", "muvmuv", "any"]

# %% [markdown]
# &, |, ^, ~, >>, <<
# * works with binary

# %% [markdown]
# #Loops
# * for (loops iterates over an iterable object)
# * while (repeats an action until a condition is no longer true)

# %%
for x in range(5):
  print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
numbers = 0
while numbers < 5:
  print(numbers)
  numbers += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
actresses_age = {
    "Love":   26,
    "Milk":   30,
    "Namtan": 30,
    "Film":   26,
    "Emi":    28,
    "Bonnie": 22
}

# %%
age = 0
index = 0

actresses_age_list = list(actresses_age.items())

while age < 28:
  actress, age = actresses_age_list[index]
  if age >=28:
    print(f"{actress} is {age} years old")
  index += 1
# Out:
# Milk is 30 years old

# %% [markdown]
# ##List Comprehensions

# %%
thai_gl_series = {
    # 2025
    "Us": 2025,
    "Reverse with Me": 2025,
    "I'm Your Moon": 2025,
    "Denied Love": 2025,
    "B-Friend": 2025,
    "Whale Store xoxo": 2025,
    "Only You": 2025,
    "Harmony Secret": 2025,
    "Somewhere Somehow": 2025,
    "Roller Coaster The Series": 2025,
    "Queendom": 2025,
    "Poisonous Love": 2025,
    "Love Design": 2025,
    "Player The Series": 2025,
    "Dangerous Queen": 2025,
    "Unlimited Love": 2025,
    "My Safe Zone": 2025,
    "ClaireBell": 2025,
    "Runaway": 2025,
    "Like a Palette": 2025,

    # 2026
    "4 Elements: The Earth": 2026,
    "Be My Angel": 2026,
    "I Wanna Be Sup'tar": 2026,
    "Heart Code": 2026,
    "Frozen Valentine": 2026,
    "Play Park": 2026,
    "My Only Sunshine": 2026,
    "Girl Rules": 2026,
    "4 Elements: The Water": 2026,
    "Broken of Love": 2026,
    "Hometown Romance": 2026,
    "Shades": 2026,
    "Fulfill": 2026,
    "Chasing Love": 2026,
    "Enemies with Benefits": 2026,
    "Love Beyond Dreams": 2026,
    "4 Elements: The Air": 2026,
    "In Love Forever": 2026,
    "AI Girl จะ Gen": 2026,
    "4 Elements: The Fire": 2026,
    "Moonshadow": 2026,
    "Under Her Rules": 2026,
}

gl_with_word_love = {x for x in thai_gl_series if "Love" in x}
len(gl_with_word_love)
# Out:
# 8

# %%
gl_with_word_love
# Out:
# {'Broken of Love',
#  'Chasing Love',
#  'Denied Love',
#  'In Love Forever',
#  'Love Beyond Dreams',
#  'Love Design',
#  'Poisonous Love',
#  'Unlimited Love'}

# %% [markdown]
# #Exercise

# %% [markdown]
# Want to find all actresses who played in series that I am interested in.

# %%
gmmtv_actresses = [
    {"actress": "Tontawan Tantivejakul (Tu)", "series": ["F4 Thailand: Boys Over Flowers", "10 Years Ticket", "Scarlet Heart Thailand", "Overdose"]},
    {"actress": "Nannaphas Loetnamchoetsakun (Mewnich)", "series": ["The Underclass", "Overdose", "Love's Echoes"]},
    {"actress": "Krongkwan Nakornthap (Jaoying)", "series": ["Wish Upon a Star"]},
    {"actress": "Chanikarn Tangkabodee (Prim)", "series": ["F4 Thailand: Boys Over Flowers"]},
    {"actress": "Tipnaree Weerawatnodom (Namtan)", "series": ["Wake Up Ladies: The Series", "Girl Rules", "HER"]},
    {"actress": "Natticha Chantaravareelekha (Fond)", "series": ["Wish Upon a Star"]},
    {"actress": "Ployshompoo Supasap (Jan)", "series": ["Enemies with Benefits"]},
    {"actress": "Prariyapit Yu (Jingjing)", "series": ["Enemies with Benefits"]},
    {"actress": "Wanwimol Jaenasavamethee (June)", "series": ["Love's Echoes"]},
    {"actress": "Benyapa Jeenprasom (View)", "series": ["Blacklist", "The Shipper", "55:15 Never Too Late", "10 Years Ticket", "Home School", "The Trainee", "23.5", "Us", "Girl Rules"]},
    {"actress": "Kanyarat Ruangrung (Piploy)", "series": ["The Shipper", "The Trainee"]},
    {"actress": "Chanitsiri Ratananimit (Waifha)", "series": ["Oxytoxin"]},
    {"actress": "Nonthakarn Kaewobchoey (Tonkhaw)", "series": ["Oxytoxin"]},
    {"actress": "Sabsima Payakharn (Pang)", "series": ["Oxytoxin"]},
    {"actress": "Yosita Wasuphiruk (Yoghurt)", "series": ["Oxytoxin"]},
    {"actress": "Nachcha Chuedang (Parn)", "series": ["Crazy Shipper", "Secret of Summer Night"]},
    {"actress": "Nuttanicha Dungwattanawanich (Nycha)", "series": ["Sapai Jao", "Nang Ai", "Plerng Prang Tian", "Watsana Rak", "Duang Jai Nai Montra"]},
    {"actress": "Ploynira Hiruntaveesin (Kapook)", "series": ["F4 Thailand: Boys Over Flowers", "The Player", "The Trainee", "Pluto", "Enemies with Benefits"]},
    {"actress": "Pattranite Limpatiyakorn (Love)", "series": ["He's Coming to Me", "2gether: The Series", "Bad Buddy", "23.5", "Whale Store xoxo", "Girl Rules"]},
    {"actress": "Rattanawadee Wongthong (Mim)", "series": ["Death Whisperer", "Death Whisperer 2", "Us", "Girl Rules"]},
]

series_interested_list = ["Us", "Girl Rules", 'Enemies with Benefits']

# %%
interested_actresses = []

for actress in gmmtv_actresses:
  interested = False

  for series_interested in series_interested_list:
    if series_interested in actress["series"]:
      interested = True
      break
  if interested:
      interested_actresses.append(actress['actress'])

interested_actresses
# Out:
# ['Tipnaree Weerawatnodom (Namtan)',
#  'Ployshompoo Supasap (Jan)',
#  'Prariyapit Yu (Jingjing)',
#  'Benyapa Jeenprasom (View)',
#  'Ploynira Hiruntaveesin (Kapook)',
#  'Pattranite Limpatiyakorn (Love)',
#  'Rattanawadee Wongthong (Mim)']

# %% [markdown]
# # Defining own function

# %%
def calculating_profit(capital, rate=10):
  return capital * (1 + rate/100)

# %%
calculating_profit(1000000)
# Out:
# 1100000.0

# %%
calculating_profit(1000000, 20)
# Out:
# 1200000.0

# %% [markdown]
# #Lambda functions

# %% [markdown]
# Calcuting for a list

# %%
x_learning_lamdba = lambda x: x+1
print(x_learning_lamdba(3))
# Out:
# 4

# %%
capital_list = [10000, 25000, 30000, 12500, 6000]
rate = 10

total_captial_list1 = [calculating_profit(capital, rate) for capital in capital_list]
print(total_captial_list1)


# using lambda

total_capital_list = [(lambda x, y: x*(1+y/100))(capital, rate) for capital in capital_list]
total_capital_list
# Out:
# [11000.0, 27500.000000000004, 33000.0, 13750.000000000002, 6600.000000000001]
# [11000.0, 27500.000000000004, 33000.0, 13750.000000000002, 6600.000000000001]

# %%
gmmtv_series = [
    {"Series Name": "23.5", "Actresses": ["Milk", "Love", "View", "June", "Ciize", "Earn"], "After 2025": False},
    {"Series Name": "Pluto", "Actresses": ["Namtan", "Film", "Ciize", "Earn", "Kapook"], "After 2025": False},
    {"Series Name": "Whale Store XOXO", "Actresses": ["Milk", 'Love', 'June', 'Mewnich', 'Piploy', "Jingjing"], "After 2025": True},
    {"Series Name": "Girl Rule", "Actresses": ['Milk', 'Love', 'Namtan', 'Film', 'View', 'Mim'], "After 2025": True},
    {"Series Name": "Us", "Actresses": ['Emi', 'Bonnie', 'View', 'Mim', 'Sing'], "After 2025": True}
]

# %% [markdown]
# Want only series that are after 2025 and with love.

# %%
list(filter(lambda series: "After 2025" and "Love" in series["Actresses"], gmmtv_series))

# filter(condition, iterator)
# if the condition is true in the item in the iterator, filter that in

for x in list(filter(lambda series: "After 2025" and "Love" in series["Actresses"], gmmtv_series)):
  print(x["Series Name"])
# Out:
# 23.5
# Whale Store XOXO
# Girl Rule
