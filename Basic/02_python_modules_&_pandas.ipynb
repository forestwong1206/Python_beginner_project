# %% [markdown]
# # Modules
#
#
# *   Like a file of pre-defined functions
# *   The Python Standard Library provides a lot of modules
# *  e.g. maths, staistics, etc.
# * https://docs.python.org/3/library/index.html

# %% [markdown]
# import modules

# %%
from statistics import mean, median, mode

number_list = [10000, 20000, 30000, 40000, 40000]

mean(number_list)
# Out:
# 28000

# %%
median(number_list)
# Out:
# 30000

# %%
mode(number_list)
# Out:
# 40000

# %% [markdown]
# Clear dataset by using modules
#
#
# *   turn string into datetime
# *   turn string into a list

# %%
from datetime import datetime
import ast

datetime.now()
# Out:
# datetime.datetime(2026, 8, 14, 9, 20, 16, 240561)

# %%
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2023-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python', 'TensorFlow', 'Deep Learning']", 'job_date': '2023-05-15'},
    {'job_title': 'Data Analyst', 'job_skills': "['SQL', 'R', 'Tableau']", 'job_date': '2023-05-10'},
    {'job_title': 'Business Intelligence Developer', 'job_skills': "['SQL', 'PowerBI', 'Data Warehousing']", 'job_date': '2023-05-08'},
    {'job_title': 'Data Engineer', 'job_skills': "['Python', 'Spark', 'Hadoop']", 'job_date': '2023-05-18'},
    {'job_title': 'AI Specialist', 'job_skills': "['Python', 'PyTorch', 'AI Ethics']", 'job_date': '2023-05-20'}
]

# %%
for job in data_science_jobs:
  job['job_date'] = datetime.strptime(job['job_date'], '%Y-%m-%d')
  job['job_skills'] = ast.literal_eval(job['job_skills'])

# %%
data_science_jobs
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': ['Python', 'SQL', 'Machine Learning'],
#   'job_date': datetime.datetime(2023, 5, 12, 0, 0)},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'TensorFlow', 'Deep Learning'],
#   'job_date': datetime.datetime(2023, 5, 15, 0, 0)},
#  {'job_title': 'Data Analyst',
#   'job_skills': ['SQL', 'R', 'Tableau'],
#   'job_date': datetime.datetime(2023, 5, 10, 0, 0)},
#  {'job_title': 'Business Intelligence Developer',
#   'job_skills': ['SQL', 'PowerBI', 'Data Warehousing'],
#   'job_date': datetime.datetime(2023, 5, 8, 0, 0)},
#  {'job_title': 'Data Engineer',
#   'job_skills': ['Python', 'Spark', 'Hadoop'],
#   'job_date': datetime.datetime(2023, 5, 18, 0, 0)},
#  {'job_title': 'AI Specialist',
#   'job_skills': ['Python', 'PyTorch', 'AI Ethics'],
#   'job_date': datetime.datetime(2023, 5, 20, 0, 0)}]

# %% [markdown]
# #Libraies
#
# * Module: a file with functions in it
# * Package: a file with modules in it
# * Library: a file with packages and modules in it
# * can be found in pipy/ conda/ python standard library

# %% [markdown]
# # Pandas
#
#
# *   A library useful for data analysis

# %% [markdown]
# Install pandas

# %%
# !pip list
#check if pandas is already in the environment, if not type !pip install panda
# Out:
# Package                               Version
# ------------------------------------- ------------------
# absl-py                               1.4.0
# accelerate                            1.14.0
# access                                1.1.10.post3
# affine                                2.4.0
# aiofiles                              25.1.0
# aiohappyeyeballs                      2.7.1
# aiohttp                               3.14.1
# aiosignal                             1.4.0
# aiosqlite                             0.22.1
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.8
# ale-py                                0.12.0
# altair                                5.5.0
# annotated-doc                         0.0.4
# annotated-types                       0.7.0
# antlr4-python3-runtime                4.9.3
# anyio                                 4.14.2
# anywidget                             0.9.21
# ...

# %%
import pandas as pd

# %% [markdown]
# Load dataset

# %%
# !pip install datasets

# %%
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/3.25k [00:00<?, ?B/s]
# data_jobs.csv: reconstructing file:   0%|          |  0.00B /  231MB
# data_jobs.csv: downloading bytes:           |  0.00B
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %% [markdown]
# We need to transform this dataset into panda

# %%
df = dataset['train'].to_pandas()

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %% [markdown]
# ##View data

# %%
df.head(10)
#show first few lines instead of top 5 and lowest 5 as default
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 7         Data Engineer                                      Data Engineer
# 8      Business Analyst           Technology & Operations Business Analyst
# 9        Data Scientist                                  Data Scientist II
#
#                    job_location             job_via         job_schedule_type  \
# ...

# %%
df.tail(3)
# Out:
#           job_title_short                                          job_title  \
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location              job_via  \
# 785738                             Malaysia     melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat  melalui Recruit.net
# 785740                                India       melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# 785738   Pekerjaan tetap               False        Malaysia
# 785739   Pekerjaan tetap               False           Sudan
# 785740   Pekerjaan tetap               False           India
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# ...

# %%
df['company_name'].head(5)
#choose the specific column to view
# Out:
# 0            Boehringer Ingelheim
# 1      Hewlett Packard Enterprise
# 2        ALPHA Augmented Services
# 3    Southwest Research Institute
# 4                 Kristina Daniel
# Name: company_name, dtype: object

# %%
df[['company_name', 'job_location']].head(5)
#rmb to use double [] for multiple column
# Out:
#                    company_name                  job_location
# 0          Boehringer Ingelheim                 Watertown, CT
# 1    Hewlett Packard Enterprise  Guadalajara, Jalisco, Mexico
# 2      ALPHA Augmented Services               Berlin, Germany
# 3  Southwest Research Institute               San Antonio, TX
# 4               Kristina Daniel                Washington, DC

# %%
df.iloc[90:100, 0:2]
#view the specific row, and column
# Out:
#          job_title_short                                          job_title
# 90        Data Scientist                                     Data Scientist
# 91        Data Scientist                                     Data Scientist
# 92         Data Engineer            Remote - Data Engineer - Permanent - W2
# 93          Data Analyst       IT Finance / TBM Data Analyst - Remote | WFH
# 94         Data Engineer                   Data Engineer - Cloud Operations
# 95         Data Engineer                                      Data Engineer
# 96         Data Engineer                                      Data Engineer
# 97          Data Analyst  Systems & Data Analyst - Exploitation, Missing...
# 98  Senior Data Engineer                         Senior Data Engineer (AWS)
# 99         Data Engineer  Senior/Staff Data Engineer – Apache Spark (Jav...

# %% [markdown]
# Investigating the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %% [markdown]
# Filtering

# %%
df.job_title_short.unique()
#array of the job title in short
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df.job_title_short == 'Data Analyst'
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737     True
# 785738    False
# 785739    False
# 785740    False
# Name: job_title_short, Length: 785741, dtype: bool

# %%
df[df.job_title_short == 'Data Analyst']
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
df[(df.job_title_short == 'Data Analyst') & (df.salary_year_avg > 100000)]
#replace & with |, represent 'or'
# Out:
#        job_title_short                                      job_title  \
# 410       Data Analyst    IT Business Lead Data Analyst - VP - Hybrid
# 1555      Data Analyst                  Data Analyst/Engineer (M/F/D)
# 1681      Data Analyst                                   Data Analyst
# 1684      Data Analyst                       Data Analyst - Data17829
# 1867      Data Analyst  Data Integration Analyst (West Coast/Chicago)
# ...                ...                                            ...
# 783588    Data Analyst                         Data Analytics Manager
# 783866    Data Analyst                Lead Credit Bureau Data Analyst
# 784033    Data Analyst                       Recruitment Data Analyst
# 785187    Data Analyst                                   Data Analyst
# 785515    Data Analyst                                   Data Analyst
#
#                        job_location               job_via job_schedule_type  \
# ...

# %%
df[(df.job_title_short == 'Data Analyst') & (df.salary_year_avg.notna())]
# .notna is those withour na in it
# Out:
#        job_title_short                                    job_title  \
# 109       Data Analyst        Senior Supply Chain Analytics Analyst
# 180       Data Analyst                             Data Analyst III
# 410       Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988       Data Analyst                        DATA ANALYST (ONSITE)
# 1413      Data Analyst                          Junior BI Developer
# ...                ...                                          ...
# 784033    Data Analyst                     Recruitment Data Analyst
# 784423    Data Analyst                           Sales Data Analyst
# 784882    Data Analyst         Merchandising Analyst (Data Analyst)
# 785187    Data Analyst                                 Data Analyst
# 785515    Data Analyst                                 Data Analyst
#
#                        job_location                job_via job_schedule_type  \
# ...

# %% [markdown]
# ##Clearing data

# %% [markdown]
# We want the date to be in the type datetime

# %%
type(df.job_posted_date)
# Out:
# pandas.core.series.Series

# %%
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %% [markdown]
# Add a new column with the job posted month

# %%
df['job_posted_month']= df.job_posted_date.dt.month
#dont use df. to create new variable or modify

# %%
df.info()
#check
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %% [markdown]
# Sorting

# %%
df.sort_values(by = 'job_posted_date', inplace=True)
#inplace to store the sort order in the df, by = is optional

# %%
df
# check
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# 351830                                      Data engineer
# ...

# %% [markdown]
# Dropping column

# %%
df.drop(labels = 'salary_hour_avg', axis = 1, inplace = True)
#axis = 1 means column, = 0 means row

# %%
df.info()
#check
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785741 entries, 108804 to 90102
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785723 non-null  object
# ...

# %% [markdown]
# Remove row with na

# %%
df.dropna(subset=['salary_year_avg'], inplace = True)
#removing the rows with salary year avg is na

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 108883 to 327439
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
# ...

# %% [markdown]
# ##Analysing data

# %% [markdown]
# Remeber to reinstall the dataset as we earlier delete some rows with na

# %%
dataset = load_dataset('lukebarousse/data_jobs')

# %%
df = dataset['train'].to_pandas()

# %% [markdown]
# checking data that is weird

# %%
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
df['salary_year_avg'].min()
# Out:
# 15000.0

# %%
min_salary = df['salary_year_avg'].idxmin()

# %%
df.iloc[min_salary]
# Out:
# job_title_short                                              Data Engineer
# job_title                                           Data Engineer - Hadoop
# job_location                                                        Brazil
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Brazil
# job_posted_date                                        2023-12-09 10:05:30
# job_no_degree_mention                                                 True
# job_health_insurance                                                 False
# job_country                                                         Brazil
# salary_rate                                                           year
# ...

# %% [markdown]
# count of types of jobs

# %%
df['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %% [markdown]
# now we want stats for a particular job type

# %%
df.groupby('job_title_short')['salary_year_avg'].min()
# Out:
# job_title_short
# Business Analyst             16500.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                15000.0
# Data Scientist               27000.0
# Machine Learning Engineer    30000.0
# Senior Data Analyst          30000.0
# Senior Data Engineer         35000.0
# Senior Data Scientist        45000.0
# Software Engineer            28000.0
# Name: salary_year_avg, dtype: float64

# %%
df.groupby(['job_title_short', 'job_country'])['salary_year_avg'].min().head(10)
# Out:
# job_title_short   job_country
# Business Analyst  Afghanistan        NaN
#                   Albania            NaN
#                   Algeria            NaN
#                   Angola             NaN
#                   Argentina      63000.0
#                   Armenia            NaN
#                   Australia      63000.0
#                   Austria            NaN
#                   Azerbaijan         NaN
#                   Bahamas            NaN
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# showing multiple operation at once

# %%
df.groupby('job_title_short')[['salary_year_avg']].agg(['min', 'max', 'median', 'count'])
# Out:
#                           salary_year_avg
#                                       min       max    median count
# job_title_short
# Business Analyst                  16500.0  387460.0   85000.0   610
# Cloud Engineer                    42000.0  280000.0   90000.0    65
# Data Analyst                      25000.0  650000.0   90000.0  5451
# Data Engineer                     15000.0  525000.0  125000.0  4500
# Data Scientist                    27000.0  960000.0  127500.0  5922
# Machine Learning Engineer         30000.0  325000.0  106415.0   576
# Senior Data Analyst               30000.0  425000.0  111175.0  1131
# Senior Data Engineer              35000.0  425000.0  147500.0  1591
# Senior Data Scientist             45000.0  890000.0  155500.0  1690
# Software Engineer                 28000.0  375000.0   99150.0   467

# %%
df.groupby('job_title_short')['salary_year_avg'].agg(['min', 'max', 'median', 'count']).sort_values(by = 'median')
# Out:
#                                min       max    median  count
# job_title_short
# Business Analyst           16500.0  387460.0   85000.0    610
# Cloud Engineer             42000.0  280000.0   90000.0     65
# Data Analyst               25000.0  650000.0   90000.0   5451
# Software Engineer          28000.0  375000.0   99150.0    467
# Machine Learning Engineer  30000.0  325000.0  106415.0    576
# Senior Data Analyst        30000.0  425000.0  111175.0   1131
# Data Engineer              15000.0  525000.0  125000.0   4500
# Data Scientist             27000.0  960000.0  127500.0   5922
# Senior Data Engineer       35000.0  425000.0  147500.0   1591
# Senior Data Scientist      45000.0  890000.0  155500.0   1690

# %%
df[df['job_country'] == 'Brazil'].groupby('job_title_short').size()
# Out:
# job_title_short
# Business Analyst              502
# Cloud Engineer                220
# Data Analyst                  599
# Data Engineer                2303
# Data Scientist                911
# Machine Learning Engineer     223
# Senior Data Analyst           138
# Senior Data Engineer          846
# Senior Data Scientist         303
# Software Engineer             987
# dtype: int64
